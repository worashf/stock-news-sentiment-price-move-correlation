# %%
import sys

from src import DataLoader

sys.path.append('../../src')

try:
    yfinance_data_loader  = DataLoader()
         # Load multiple stocks
    tickers = ['AAPL', 'MSFT', 'GOOG','AMZN','NVDA','TSLA','META']
    stock_data = yfinance_data_loader.load_multiple_stocks(tickers)

        # Display sample of loaded data
    for ticker in tickers:
            print(f"Sample {ticker} data:")
            print(stock_data[ticker].head(3))
            print("\nData info:")
            print(stock_data[ticker].info())

            # Check for missing values
            print(f"Missing values check for {ticker}:")
            print(stock_data[ticker].isnull().sum())

except Exception as e:
        print(f"Data loading failed: {str(e)}")
# Out:
# /Users/worash/Desktop/tenx/predict-price-move-with-sentment/src/utils/yfinance_data_utils.py:93: UserWarning: Potential price outliers detected in Open for AAPL
#   warnings.warn(f"Potential price outliers detected in {col} for {ticker}")
# /Users/worash/Desktop/tenx/predict-price-move-with-sentment/src/utils/yfinance_data_utils.py:93: UserWarning: Potential price outliers detected in High for AAPL
#   warnings.warn(f"Potential price outliers detected in {col} for {ticker}")
# /Users/worash/Desktop/tenx/predict-price-move-with-sentment/src/utils/yfinance_data_utils.py:93: UserWarning: Potential price outliers detected in Low for AAPL
#   warnings.warn(f"Potential price outliers detected in {col} for {ticker}")
# /Users/worash/Desktop/tenx/predict-price-move-with-sentment/src/utils/yfinance_data_utils.py:93: UserWarning: Potential price outliers detected in Close for AAPL
#   warnings.warn(f"Potential price outliers detected in {col} for {ticker}")
# ...
